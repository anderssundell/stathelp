# %%
test <- c(5, 7, 8)
test2 <- c(1, 2, 2)
test3 <- as.data.frame(cbind(test, test2))

# %%
library(tidyverse);

# %%
ggplot(test3, aes(x = test, y = test2)) +
geom_point()
# Out:
# plot without title
